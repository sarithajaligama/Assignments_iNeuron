# %% [markdown]
# ### Scipy
#
# We have the min and max temperatures in a city In India for each months of the year. We would like to find a function to describe this and show it graphically, the dataset given below.
#
# **Task:**
#
# 1. fitting it to the periodic function
# 2. plot the fit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import optimize
from numpy.random import randn, randint, uniform, sample

# %%
from IPython.display import Image
Image(filename = '01.png', width =500)

# %%
Max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
Min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])
Month = np.arange(12)

# %%
plt.plot(Month, Max, 'ro')
plt.plot(Month, Min, 'bo') 
plt.xlabel('Month') 
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %% [markdown]
# ***Fitting it to the periodic function***

# %%
def yearly_temp(times, avg, ampl, time_offset):
    return (avg
            + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))

res_max, cov_max = optimize.curve_fit(yearly_temp, Month,
                                      Max, [20, 10, 0])
res_min, cov_min = optimize.curve_fit(yearly_temp, Month,
                                      Min, [-40, 20, 0])

# %% [markdown]
# ***Plot the fit***

# %%
days = np.linspace(0, 12, num=365)

plt.figure()
plt.plot(Month, Max, 'ro')
plt.plot(days, yearly_temp(days, *res_max), 'r-')
plt.plot(Month, Min, 'bo')
plt.plot(days, yearly_temp(days, *res_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')

plt.show()

# %% [markdown]
# ### Matplotlib:
#
# This assignment is for visualization using matplotlib:
#
# **data to use:**
#
# url = https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv
#
# titanic = pd.read_csv(url)
#
# **Charts to plot:**
#
# 1. Create a pie chart presenting the male/female proportion
#
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
url = 'https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'

# %%
titanic = pd.read_csv(url,skip_blank_lines=True)

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
female_male = titanic.sex.value_counts()

# %%
Gender = ['Male', 'Female']
Colors = ['y', 'c']
plt.pie(female_male, labels = Gender, colors = Colors, startangle = 90, autopct='%.1f%%')
plt.show()

# %%
Female = titanic[titanic.sex == 'female'][['fare', 'age']]
Male = titanic[titanic.sex == 'male'][['fare', 'age']]

# %%
plt.scatter(x = Male['fare'], y = Male['age'], color= 'y')
plt.scatter(x = Female['fare'], y = Female['age'], color= 'c')
plt.show()
